# %% [markdown]
# <a href="https://colab.research.google.com/github/sarahatiqah/Data-Visualization-Tools/blob/main/Python_BenchmarkTask.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Activities 1 : Setup and Install**

# %%
#################################################################
## PLEASE PUT THE TIME TOOK FOR INSTALLATION
## START TIME : 12:02:22
## END TIME : 12:02:41
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# # **Activities 2 : Import python libraries relevant for data visualization**

# %% [markdown]
# Task 02 : Importing relevant packages with their alias

# %%
#################################################################
## START TIME :12:03:10

# %%
# Task 02 : Importing relevant packages with their alias

import pandas as pd                 # fast, powerful, flexible and easy to use open source data analysis and manipulation tool
import matplotlib.pyplot as plt     # plotting library used for 2D graphics in python programming language
import matplotlib                   # comprehensive library for creating static, animated, and interactive visualizations in Python
import seaborn as sns               # Python data visualization library based on matplotlib

# %%
#################################################################
## END TIME : 12:03:55
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# # **Activities 3 : Load the data source given into this workspace and rename the data with suitable name variable.**

# %% [markdown]
# Task 03 : Load health data for analysis from the https://github.com/arifjamal89/data_visualization_tools

# %%
#################################################################
## START TIME : 12:04:08

# %%
# Task 03 : Load health data for analysis
smh = pd.read_csv('Student_Mental_health.csv')

# %%
#################################################################
## END TIME : 12:05:40
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# # **Activities 4 : Understanding the data.**

# %% [markdown]
# Task 04 : Print top5 data/ header of DataFrame

# %%
#################################################################
## START TIME : 12:06:12

# %%
# Task 04 : Print top5 data/ header of DataFrame

smh.head()
# Out:
#           Timestamp Choose your gender  Age What is your course?  \
# 0  08/07/2020 12:02             Female   18          Engineering
# 1  08/07/2020 12:04               Male   21    Islamic education
# 2  08/07/2020 12:05               Male   19                  BIT
# 3  08/07/2020 12:06             Female   22                 Laws
# 4  08/07/2020 12:13               Male   23         Mathemathics
#
#   Your current year of Study What is your CGPA? Marital status  \
# 0                     Year 1        3.00 - 3.49             No
# 1                     Year 2        3.00 - 3.49             No
# 2                     Year 1        3.00 - 3.49             No
# 3                     Year 3        3.00 - 3.49            Yes
# 4                     Year 4        3.00 - 3.49             No
#
#   Do you have Depression? Do you have Anxiety? Do you have Panic attack?  \
# 0                     Yes                   No                       Yes
# 1                      No                  Yes                        No
# 2                     Yes                  Yes                       Yes
# 3                     Yes                   No                        No
# 4                      No                   No                        No
#
#   Did you seek any specialist for a treatment?
# 0                                           No
# 1                                           No
# 2                                           No
# 3                                           No
# 4                                           No

# %%
#################################################################
## END TIME : 12:08:29
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 05 : Display all the columns from the data set

# %%
#################################################################
## START TIME : 12:08:41

# %%
# Task 05
smh.columns
# Out:
# Index(['Timestamp', 'Gender', 'Age', 'What is your course?',
#        'Your current year of Study', 'What is your CGPA?', 'Marital status',
#        'Do you have Depression?', 'Do you have Anxiety?',
#        'Do you have Panic attack?',
#        'Did you seek any specialist for a treatment?'],
#       dtype='object')

# %%
#################################################################
## END TIME : 12:09:29
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 06 : Rename the columns with a suitable name

# %%
#################################################################
## START TIME :

# %%
# Task 06 
smh.columns = ['Timestamp', 'Gender', 'Age', 'Course',
       'Current year of Study', 'CGPA', 'Marital status',
       'Depression', 'Anxiety',
       'Panic attack',
       'Did you seek any specialist for a treatment?']

# %%
#################################################################
## END TIME : 12:11:09
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 07 : Display data types for each column from the data set

# %%
#################################################################
## START TIME : 12:11:09

# %%
# Task 07 
smh.dtypes
# Out:
# Timestamp                                       object
# Gender                                          object
# Age                                              int64
# Course                                          object
# Current year of Study                           object
# CGPA                                            object
# Marital status                                  object
# Depression                                      object
# Anxiety                                         object
# Panic attack                                    object
# Did you seek any specialist for a treatment?    object
# dtype: object

# %%
#################################################################
## END TIME : 12:11:48
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# # **Activities 5 : Visualize the data.**

# %% [markdown]
# Task 08 : What was the ***depression*** rate?

# %%
#################################################################
## START TIME : 12:12:03

# %%
#
# Task 08
# Set initial plot options
sns.set_style('white')
plt.figure(figsize = (12, 8))

# Countplot
sns.catplot(x ="Depression", 
            hue ="Depression",
kind ="count", data = smh)

# %%
#################################################################
## END TIME : 12:17:18
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 09 - What was the ***anxiety rate*** by ***gender***?

# %%
#################################################################
## START TIME : 12:17:30

# %%
#
# Task 09

# Set initial plot options
sns.set_style('white')
plt.figure(figsize = (12, 8))

# Countplot
sns.catplot(x ="Gender", 
            hue ="Anxiety",
kind ="count", data = smh)

# %%
#################################################################
## END TIME : 12:20:53
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 10 - What was the ***depression rate*** by ***courses***?

# %%
#################################################################
## START TIME :

# %%
#
# Task 10
# Set initial plot options
sns.set_style('darkgrid')
fig = plt.figure()
plt.figure(figsize = (300, 100))

# Countplot
sns.catplot(x ="Course", 
            hue ="Depression",
kind ="count", data = smh,
height=8, aspect=3)

# %%
#################################################################
## END TIME : 12:28
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 11 - What is the ***distribution of student ages*** using distribution plot? Set the ***binwidth = 1***

# %%
#################################################################
## START TIME : 12:29:57

# %%
#
# Task 11

dit = sns.displot(smh, x="Age",binwidth=1)
dit.fig.suptitle('Student Age Distribtion',fontsize=16)
# Out:
# Text(0.5, 0.98, 'Student Age Distribtion')

# %%
#################################################################
## END TIME : 12:32:06
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 12 - What are the ***Panic Attack rates by age*** using distribution plot? Set the ***binwidth = 1***

# %%
#################################################################
## START TIME :

# %%
#
# Task 12

dit = sns.displot(smh, x="Age",hue="Panic attack",element="step",binwidth=1)
dit.fig.suptitle('Panic Attack Rate by Age',fontsize=16)
# Out:
# Text(0.5, 0.98, 'Panic Attack Rate by Age')

# %%
#################################################################
## END TIME : 12:35:08
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 13 - Use ***Box plot*** to display ***depression rate*** by ***age***

# %%
#################################################################
## START TIME : 12:35:20

# %%
#Task 13

plt.figure(figsize=(8,8))
sns.boxplot(x="Depression", y="Age", data=smh)
plt.show()

# %%
#################################################################
## END TIME : 12:39:04
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 14 - Use ***Bar plot*** to display ***depression rate by cgpa***

# %%
#################################################################
## START TIME : 12:39:34

# %%
#
# Task 14

# Set initial plot options
sns.set_style('white')
plt.figure(figsize = (15, 3))

# Countplot
sns.catplot(x ="CGPA", 
            hue ="Depression",
kind ="count", data = smh)

# %%
#################################################################
## END TIME : 12:46:51
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 15 - Use ***Bar plot*** to display ***anxiety rate by cgpa***

# %%
#################################################################
## START TIME :

# %%
#
# Task 15

# Set initial plot options
sns.set_style('white')
plt.figure(figsize = (15, 3))

# Countplot
sns.catplot(x ="CGPA", 
            hue ="Anxiety",
kind ="count", data = smh)

# %%
#################################################################
## END TIME : 12:48:22
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 16 - Use ***bar plot*** to display ***depression rate by current year study***

# %%
#################################################################
## START TIME : 12:50:28

# %%
#
# Task 16

# Set initial plot options
sns.set_style('white')
plt.figure(figsize = (15, 3))

# Countplot
sns.catplot(x ="Current year of Study", 
            hue ="Depression",
kind ="count", data = smh)

# %%
#################################################################
## END TIME : 12:53:11
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# Task 17 - What was the ***treatment rate by depression rate and gender***?
# Understanding those student who have depression are seeking help for specialist treatment.

# %%
#################################################################
## START TIME : 12:54:22

# %%
#
# Task 17

# initialize the FacetGrid object
g = sns.FacetGrid(smh, col='Did you seek any specialist for a treatment?', row='Depression')
g.map(plt.hist, 'Gender')
g.add_legend()
plt.show()

# %%
#################################################################
## END TIME : 12:57:55
## BETWEEN 1 - 5 WHAT IS YOUR CONFIDENCE LEVEL FOR THE TASK
## ANSWER : 5

# %% [markdown]
# # **END Task : Questionnaire Survey.**

# %% [markdown]
# After finishing the task please click on File -> Download -> Download .ipynb and email your work to arifjamal89@gmail.com
#
#
# Please answer the usability questionnaire below
#
# Link : https://forms.gle/3QBCASrbjjzjGDGA9
#
# Link Post Test : https://forms.gle/92k7tpEpMHA35LvSA
